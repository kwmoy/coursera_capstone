# %% [markdown]
# # IBM Data Science Capstone Project - Kevin Moy
# Note: This project is a rework of the previous YMCA DS notebook. The updated version includes explicit showcasing of the elbow method, which determines the number of clusters chosen for the KMeans algorithm.
# ### Contacting Kevin Moy
# Please contact Kevin Moy with feedback or just to chat!:
#
# <b>LinkedIn</b> <a href="https://www.linkedin.com/in/kevin-moy/">https://www.linkedin.com/in/kevin-moy/</a>
#
# <b>E-mail</b> <a href="mailto:kmoy1@terpmail.umd.edu">kmoy1@terpmail.umd.edu</a>

# %% [markdown]
# ### About the Course
# This notebook is the Data Science Capstone project for the IBM Data Science Certificate. The official prompt is printed below:
#
# "_Now that you have been equipped with the skills and the tools to use location data to explore a geographical location, over the course of two weeks, you will have the opportunity to be as creative as you want and come up with an idea to leverage the Foursquare location data to explore or compare neighborhoods or cities of your choice or to come up with a problem that you can use the Foursquare location data to solve. If you cannot think of an idea or a problem, here are some ideas to get you started:_
#
# _In Module 3, we explored New York City and the city of Toronto and segmented and clustered their neighborhoods. Both cities are very diverse and are the financial capitals of their respective countries. One interesting idea would be to compare the neighborhoods of the two cities and determine how similar or dissimilar they are. Is New York City more like Toronto or Paris or some other multicultural city? I will leave it to you to refine this idea._
# _In a city of your choice, if someone is looking to open a restaurant, where would you recommend that they open it? Similarly, if a contractor is trying to start their own business, where would you recommend that they setup their office?_"

# %% [markdown]
# # Background for this notebook, with Outline
# Please see the supporting documents within <a href="https://github.com/kwmoy/coursera_capstone"> my capstone project folder</a>. Only a cursory background will be provided here.
#
# __The client, the YMCA of Greater Toronto, has requested an upcoming Data Scientist, Kevin Moy, to identify an area within the City of Toronto to test a novel youth development center and program. The client identified that this area must be a high-risk area, with access to a large density of at-risk students. If this effort is found to be successful, the program will be expanded to other YMCA of Greater Toronto locations.__
#
# Rough outline, reflected in Table of Contents
#
# 1. Create a unified dataset of Crime/Population, Population Density, and Community Center Density.
#     1. Use a Toronto crime dataset - it gives crime, population, area of neighborhood - to calculate Crime / Population, Population Density.
#     2. Use a Foursquare dataset to find how many community centers are in the vicinity (2000 meters) of each Neighborhood in step 1. Make sure we can unify these datasets by neighborhood.
#     3. Using steps 1 and 2, calculate the community center density.
#     4. Each of the key measures, Crime/Population, Population Density, and Community Center Density are assigned to a location (longitude and latitude)
#
# 2. With this unified dataset, cluster neighborhoods based on their Crime/Population, Population Density, and Community Center Density stats
#     1. Analyze and characterize each cluster of neighborhoods.
#     2. Make a recommendation of which neighborhood and cluster of neighborhoods would benefit most from the YMCA's improvement efforts.

# %% [markdown]
# # Table of Contents
# 1. [Section 1: Create a Dataset with Crime Data, Population, Area, and Location Data](#s1)
#     1. [Download Packages](#s11)
#     2. [Crime Dataset Transformations](#s12)
#         1. [Question: Are there standout crime-ridden locations in Toronto that we need to immediately address? (part i)](#s121)
#         2. [Question: Developing a Measure for Crime](#s122)
#         3. [Question: Are there standout crime-ridden locations in Toronto that we need to immediately address? (part ii)](#s123)
#     3. [Neighborhood Dataset](#s13)
#     4. [Combine the Crime and Neighborhood DataFrame](#s14)
# 2. [Section 2: Finding the Community and Youth Centers of Toronto using Foursquare](#s2)
#     1. [Foursquare Credentials](#s21)
#     2. [Defining the Search](#s22)
#     3. [Collect Community Centers within 1 km of Neighborhood Centers](#s23)
#     4. [Create Dataframe with Crime, Population, and Community Center Info](#s24)
#     5. [Defining the Data Frame](#s25)
# 3. [Section 3: Finding the Best Location for Our Youth Center Pilot Facility](#s3)
#     1. [Question: Are youth centers generally established in places of most need?](#s31)
#     2. [Question: Can we find a cluster of neighborhoods that need YMCAs?](#s32)
#         1. [Cluster each Neighborhood](#s321)
#         2. [Show Clusters on Folium Map](#s322)
#         3. [Interpreting our Clusters](#s323)
# 4. [Section 4: Neighborhood Choice](#s4)

# %% [markdown]
# ## 1. Create a Dataset with Crime Data, Population, Area, and Location Data <a name="s1"></a>

# %% [markdown]
# ### 1.1 Download Packages <a name="s11"></a>

# %%
# Download necessary packages
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1g-h516909a_0 --> 1.1.1g-h516909a_1
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ### 1.2 Crime Dataset Transformations <a name="s12"></a>
# Create a dataset including a crime score, land area, population, and neighborhood.

# %%
# Download Crime Dataset through API
import requests
api_link = 'https://services.arcgis.com/S9th0jAJ7bqgIRjw/arcgis/rest/services/Neighbourhood_MCI/FeatureServer/0/query?where=1%3D1&outFields=Neighbourhood,Hood_ID,Population,TheftOver_Rate_2019,Shape__Area,Robbery_Rate_2019,Homicide_Rate_2019,BreakandEnter_Rate_2019,AutoTheft_Rate_2019,Assault_Rate_2019&outSR=4326&f=json'
crime_json = requests.get(api_link).json()
df_crime = [neighborhood['attributes'] for neighborhood in crime_json['features']]

# Note the Crime Rate is normalized per 100,000 people in the population
df_crime = pd.json_normalize(df_crime)
df_crime.head()
# Out:
#              Neighbourhood Hood_ID  Population  TheftOver_Rate_2019  \
# 0           Yonge-St.Clair     097       12528                 47.9
# 1  York University Heights     027       27593                101.5
# 2         Lansing-Westgate     038       16164                 68.1
# 3       Yorkdale-Glen Park     031       14804                195.9
# 4      Stonegate-Queensway     016       25051                 16.0
#
#     Shape__Area  Robbery_Rate_2019  Homicide_Rate_2019  \
# 0  1.161315e+06               31.9                 0.0
# 1  1.324666e+07              286.3                 0.0
# 2  5.346186e+06               68.1                 0.0
# 3  6.038326e+06              283.7                 6.8
# 4  7.946202e+06               87.8                 0.0
#
#    BreakandEnter_Rate_2019  AutoTheft_Rate_2019  Assault_Rate_2019
# 0                    223.5                 47.9              295.3
# 1                    391.4                521.9             1340.9
# 2                    241.3                198.0              445.4
# 3                    567.4                412.1             1411.8
# 4                    255.5                135.7              327.3

# %%
# Create a risk score, which measures risk of listed crimes.

# First, we will scale all crimes to the min/max, homocide has scale 10
# Then, normalize these crimes. We can say neighborhoods 1 standard deviation above the mean is top 32% most dangerous

# Scale all crimes except Homicide
from sklearn.preprocessing import StandardScaler # for normalization
scaler = StandardScaler()
crimes = ['TheftOver_Rate_2019','Robbery_Rate_2019','BreakandEnter_Rate_2019','AutoTheft_Rate_2019','Assault_Rate_2019','Homicide_Rate_2019']

print('Max homicide rate is: ' + str(max(df_crime['Homicide_Rate_2019'])))
# Define function that that scales numbers in a np array
def ScaleMinMax(array):
    scaled_array = (array - min(array))/(max(array)-min(array))
    return scaled_array

# Scale all crimes, multiply homicide by 10
for crime in crimes:
    df_crime[crime] = ScaleMinMax(df_crime[crime])
df_crime['Homicide_Rate_2019'] = 10 * df_crime['Homicide_Rate_2019']
#df_crime_normalize = scaler.fit(df_crime[moderate_crimes]).transform(df_crime[moderate_crimes])
#df_crime2 = df_crime[:]
#df_crime2[moderate_crimes] = df_crime_normalize

df_crime.head()
# Out:
# Max homicide rate is: 24.2
#              Neighbourhood Hood_ID  Population  TheftOver_Rate_2019  \
# 0           Yonge-St.Clair     097       12528             0.169258
# 1  York University Heights     027       27593             0.358657
# 2         Lansing-Westgate     038       16164             0.240636
# 3       Yorkdale-Glen Park     031       14804             0.692226
# 4      Stonegate-Queensway     016       25051             0.056537
#
#     Shape__Area  Robbery_Rate_2019  Homicide_Rate_2019  \
# 0  1.161315e+06           0.036936            0.000000
# 1  1.324666e+07           0.422041            0.000000
# 2  5.346186e+06           0.091735            0.000000
# 3  6.038326e+06           0.418105            2.809917
# 4  7.946202e+06           0.121556            0.000000
#
#    BreakandEnter_Rate_2019  AutoTheft_Rate_2019  Assault_Rate_2019
# 0                 0.105284             0.015343           0.039591
# 1                 0.218600             0.348958           0.348054
# 2                 0.117298             0.120988           0.083872
# 3                 0.337383             0.271678           0.368971
# 4                 0.126881             0.077140           0.049031

# %% [markdown]
# #### 1.2.1 Question: Are there standout crime-ridden locations in Toronto that we need to immediately address? (part i) <a name="s121"></a>
# We briefly explore distributions of numerical variables on each different type of crime in Toronto.

# %%
# Use Describe method on df_crime dataset
df_crime[crimes].describe()
# Out:
#        TheftOver_Rate_2019  Robbery_Rate_2019  BreakandEnter_Rate_2019  \
# count           140.000000         140.000000               140.000000
# mean              0.166545           0.174559                 0.160661
# std               0.146567           0.130658                 0.146304
# min               0.000000           0.000000                 0.000000
# 25%               0.080389           0.095141                 0.071590
# 50%               0.132155           0.146382                 0.128973
# 75%               0.193110           0.213556                 0.198235
# max               1.000000           1.000000                 1.000000
#
#        AutoTheft_Rate_2019  Assault_Rate_2019  Homicide_Rate_2019
# count           140.000000         140.000000          140.000000
# mean              0.112236           0.163214            1.234357
# std               0.119392           0.147004            1.988511
# min               0.000000           0.000000            0.000000
# 25%               0.053984           0.068207            0.000000
# 50%               0.085234           0.127297            0.000000
# 75%               0.121868           0.210808            2.365702
# max               1.000000           1.000000           10.000000

# %% [markdown]
# __Analysis:__ Note: Homicide rate is scaled, but to 10 instead of 1. It seems that all crime except the Auto Theft Rate, has an upper quartile around 20% of the maximum crime rate. Additionally, there are 50+% of neighborhoods with a 0% homicide rate in 2019. The Homicide rate has the largest standard deviation of all crimes.
#
# __Takeaways:__ All the crimes are skew right, homicides especially so. There are outliers in every single category (meaning: crime rate > (1.5 * IQR)+ crime rate(@ 75%)). This means Toronto has neighborhoods with standout crime-ridden locations to immediately address. Let's create a single measure to find the most vulnerable locations.

# %% [markdown]
# #### 1.2.2 Question: Developing a Measure for Crime <a name="s122"></a>
# All crimes are scaled from 0 to 1. However, not all crime is equally disastrous. The model considers homicide to be worth 10x all other crimes in making an area dangerous. We roll these numbers into one column.

# %%
# Add all crimes into one score, then normalize
df_crime['Crime_Score'] = df_crime[crimes].sum(axis=1)
crime_score = np.array(df_crime['Crime_Score']).reshape(-1,1) # reshaping needed to feed StandardScaler
df_crime_score_normalize = scaler.fit(crime_score).transform(crime_score)
df_crime['Crime_Score'] = df_crime_score_normalize

df_crime.head()
# Out:
#              Neighbourhood Hood_ID  Population  TheftOver_Rate_2019  \
# 0           Yonge-St.Clair     097       12528             0.169258
# 1  York University Heights     027       27593             0.358657
# 2         Lansing-Westgate     038       16164             0.240636
# 3       Yorkdale-Glen Park     031       14804             0.692226
# 4      Stonegate-Queensway     016       25051             0.056537
#
#     Shape__Area  Robbery_Rate_2019  Homicide_Rate_2019  \
# 0  1.161315e+06           0.036936            0.000000
# 1  1.324666e+07           0.422041            0.000000
# 2  5.346186e+06           0.091735            0.000000
# 3  6.038326e+06           0.418105            2.809917
# 4  7.946202e+06           0.121556            0.000000
#
#    BreakandEnter_Rate_2019  AutoTheft_Rate_2019  Assault_Rate_2019  \
# 0                 0.105284             0.015343           0.039591
# 1                 0.218600             0.348958           0.348054
# 2                 0.117298             0.120988           0.083872
# 3                 0.337383             0.271678           0.368971
# 4                 0.126881             0.077140           0.049031
#
#    Crime_Score
# 0    -0.747775
# 1    -0.143295
# 2    -0.616817
# 3     1.312097
# 4    -0.718352

# %% [markdown]
# #### 1.2.3 Question: Are there standout crime-ridden locations in Toronto that we need to immediately address? (part ii) <a name="s123"></a>
#
# Using this new measure for crime, we create a box plot to explore the distribution. If there are few outliers on the dangerous side, this makes the first YMCA location an easy choice.

# %%
# Narrow dataframe to eliminate specific crimes
df_crime2 = df_crime.drop(crimes,axis=1)
df_crime2.head()
# Out:
#              Neighbourhood Hood_ID  Population   Shape__Area  Crime_Score
# 0           Yonge-St.Clair     097       12528  1.161315e+06    -0.747775
# 1  York University Heights     027       27593  1.324666e+07    -0.143295
# 2         Lansing-Westgate     038       16164  5.346186e+06    -0.616817
# 3       Yorkdale-Glen Park     031       14804  6.038326e+06     1.312097
# 4      Stonegate-Queensway     016       25051  7.946202e+06    -0.718352

# %%
# Create a boxplot to show distribution of the crime_score
import seaborn as sns
sns.boxplot(y='Crime_Score',data=df_crime2)
# Out:
# <AxesSubplot:ylabel='Crime_Score'>

# %% [markdown]
# __Analysis:__ The box plot appears to have seven outliers. As expected when analyzing data for each crime type, the data is heavily skew right (up).
#
# __Takeaways:__ One neighborhood in particular is greater than 4 standard deviations above the normalized crime_score.

# %% [markdown]
# ### 1.3 Neighborhood Dataset <a name="s13"></a>
# Create a dataframe with latitude, longitude, and neighborhood

# %%
url = 'https://ckan0.cf.opendata.inter.prod-toronto.ca/download_resource/a083c865-6d60-4d1d-b6c6-b0c8a85f9c15?format=csv&projection=4326'
#neighborhood_csv=requests.get(url).csv()
#neighborhood_csv
#df_neighborhood = neighborhood_json

import csv # import package to process csvs



#with requests.Session() as s:
#    download = s.get(url)

#    decoded_content = download.content.decode('utf-8')

#    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
#    my_list = list(cr)
##    for row in my_list:
##        print(row)
        
df_neighborhood=pd.read_csv(url)
df_neighborhood.head()
# Out:
#     _id   AREA_ID  AREA_ATTR_ID  PARENT_AREA_ID  AREA_SHORT_CODE  \
# 0  7001  25886861      25926662           49885               94
# 1  7002  25886820      25926663           49885              100
# 2  7003  25886834      25926664           49885               97
# 3  7004  25886593      25926665           49885               27
# 4  7005  25886688      25926666           49885               31
#
#    AREA_LONG_CODE                     AREA_NAME                     AREA_DESC  \
# 0              94                 Wychwood (94)                 Wychwood (94)
# 1             100          Yonge-Eglinton (100)          Yonge-Eglinton (100)
# 2              97           Yonge-St.Clair (97)           Yonge-St.Clair (97)
# 3              27  York University Heights (27)  York University Heights (27)
# 4              31       Yorkdale-Glen Park (31)       Yorkdale-Glen Park (31)
#
#     X   Y  LONGITUDE   LATITUDE  OBJECTID   Shape__Area  Shape__Length  \
# 0 NaN NaN -79.425515  43.676919  16491505  3.217960e+06    7515.779658
# 1 NaN NaN -79.403590  43.704689  16491521  3.160334e+06    7872.021074
# 2 NaN NaN -79.397871  43.687859  16491537  2.222464e+06    8130.411276
# 3 NaN NaN -79.488883  43.765736  16491553  2.541821e+07   25632.335242
# 4 NaN NaN -79.457108  43.714672  16491569  1.156669e+07   13953.408098
#
#                                             geometry
# 0  {u'type': u'Polygon', u'coordinates': (((-79.4...
# 1  {u'type': u'Polygon', u'coordinates': (((-79.4...
# 2  {u'type': u'Polygon', u'coordinates': (((-79.3...
# 3  {u'type': u'Polygon', u'coordinates': (((-79.5...
# 4  {u'type': u'Polygon', u'coordinates': (((-79.4...

# %% [markdown]
# #### Neighborhood DataFrame

# %%
# Take the useful columns
df_neighborhood = df_neighborhood[['AREA_LONG_CODE','LONGITUDE','LATITUDE']]
df_neighborhood.rename(columns={'AREA_LONG_CODE':'Hood_ID'},inplace=True)
df_neighborhood.head()
# Out:
#    Hood_ID  LONGITUDE   LATITUDE
# 0       94 -79.425515  43.676919
# 1      100 -79.403590  43.704689
# 2       97 -79.397871  43.687859
# 3       27 -79.488883  43.765736
# 4       31 -79.457108  43.714672

# %%
type(df_crime2['Hood_ID'])
type(df_crime2['Hood_ID'].astype('int64'))
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 1.4 Combine the Crime and Neighborhood DataFrame <a name="s14"></a>

# %%
# Make Hood_ID values the same data type
print('hood_ID on df_neighborhood is type '+str(type(df_neighborhood['Hood_ID'].values[0])))
print('hood_ID on df_crime2 is type '+str(type(df_crime2['Hood_ID'].values[0])))

df_crime2['Hood_ID'] = df_crime2['Hood_ID'].astype('int64')
print('hood_ID on df_crime2 is type '+str(type(df_crime2['Hood_ID'].values[0])))



# Create a neighborhood dataframe with top 10 venues
#toronto_merged = toronto_df
#toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
#toronto_merged.head()
# Out:
# hood_ID on df_neighborhood is type <class 'numpy.int64'>
# hood_ID on df_crime2 is type <class 'str'>
# hood_ID on df_crime2 is type <class 'numpy.int64'>

# %%
# Join the df_neighborhood and df_crime2 DataFrames
df_crimes = df_neighborhood
df_crimes = df_neighborhood.join(df_crime2.set_index('Hood_ID'),on='Hood_ID')
df_crimes.head()
# Out:
#    Hood_ID  LONGITUDE   LATITUDE            Neighbourhood  Population  \
# 0       94 -79.425515  43.676919                 Wychwood       14349
# 1      100 -79.403590  43.704689           Yonge-Eglinton       11817
# 2       97 -79.397871  43.687859           Yonge-St.Clair       12528
# 3       27 -79.488883  43.765736  York University Heights       27593
# 4       31 -79.457108  43.714672       Yorkdale-Glen Park       14804
#
#     Shape__Area  Crime_Score
# 0  1.682111e+06     0.572987
# 1  1.650438e+06     1.107409
# 2  1.161315e+06    -0.747775
# 3  1.324666e+07    -0.143295
# 4  6.038326e+06     1.312097

# %% [markdown]
# ## 2. Finding the Community and Youth Centers of Toronto using Foursquare <a name="s2"></a>
# This step allows us to find where in Toronto either does not have a youth center available to its young population, or has a low density of youth centers when compared to its population.

# %% [markdown]
# ### 2.1 Foursquare Credentials <a name='s21'></a>

# %%
print('Credentials Entered!')
# Out:
# Credentials Entered!

# %% [markdown]
# ### 2.2 Defining the Search <a name='s22'></a>
# We seek to find youth and community centers. After a brief search using Foursquare, here is what we are looking for, and why:
#  - Community Centers.
#      - Example: Waterfront Neighbourhood Centre in Toronto has children's programs serving preschool ages (3-5 y/o), children (5-12 y/o), and youth (13-24 y/o). It also has community programs like Nutrition Services. <a href="https://waterfrontnc.ca/programs-services/community-programs-and-services/?fwp_sessions=winter">Accessed 3 May 2020.</a>
#      - Example: Mitchell Field Community Centre in Toronto has camps, fitness, and sports. <a href="https://www.toronto.ca/data/parks/prd/facilities/complex/693/index.html">Accessed 3 May 2020.</a>
#  - Gyms (select YMCAs and Jewish Community Centers, and anything including "Community")
#      - Example: Jewish Community Centres, YMCAs, and North Toronto Memorial Community Centre (which has youth programs, <a href="https://pointinc.org/community-events-rec/north-toronto-memorial-community-centre/">Accessed 3 May 2020</a>).

# %%
# Get top 100 venues in Northwest within 1000 meters, first row in toronto_df
neighborhood_latitude = df_crimes['LATITUDE'][0]
neighborhood_longitude = df_crimes['LONGITUDE'][0]
radius = 1000 # any community centers must be accessible, within one kilometer

comm_center, gym = '52e81612bcbc57f1066b7a34', '4bf58dd8d48988d175941735'
categories = comm_center+','+gym

url = 'https://api.foursquare.com/v2/venues/search?ll={},{}&client_id={}&client_secret={}&radius={}&v={}&limit={}&categoryId={}'.format(neighborhood_latitude,neighborhood_longitude,CLIENT_ID,CLIENT_SECRET,radius,VERSION,LIMIT,categories)


results = requests.get(url).json()

# %%
# Define a function to get categories of each venue fed
def get_category_type(row):
    try: 
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
results['response']['venues'] # access list of results
first_result = results['response']['venues'][0] # access first result

# we find that ['location']['lat'], ['location']['lng'], ['name'], and ['categores'][0]['name'] are relevant
result_latitude = first_result['location']['lat']
result_longitude = first_result['location']['lng']
result_name = first_result['name']
result_category = get_category_type(first_result)

print('Latitude, longitude, name, and category are: {}, {}, {}, {}'.format(result_latitude,result_longitude,result_name,result_category))
# Out:
# Latitude, longitude, name, and category are: 43.68165411662311, -79.42590420627609, Rocket Cycle, Cycle Studio

# %% [markdown]
# ### 2.3 Collect Community Centers within 1 km of Neighborhood Centers <a name='s23'></a>

# %%
# need a dataset that gives each neighborhood's number, w/ venue name, latitude, and longitude
df_community = []

for lat, lng, hood in zip(df_crimes['LATITUDE'],df_crimes['LONGITUDE'],df_crimes['Hood_ID']):
    neighborhood_latitude = lat
    neighborhood_longitude = lng
    neighborhood = hood
    radius = 1000
    url = 'https://api.foursquare.com/v2/venues/search?ll={},{}&client_id={}&client_secret={}&radius={}&v={}&limit={}&categoryId={}'.format(neighborhood_latitude,neighborhood_longitude,CLIENT_ID,CLIENT_SECRET,radius,VERSION,LIMIT,categories)
    results = requests.get(url).json()
    for result in results['response']['venues']:
        result_latitude = result['location']['lat']
        result_longitude = result['location']['lng']
        result_name = result['name']
        df_community.append([hood,lat,lng,result_latitude,result_longitude,result_name])

# %%
df_community[0:5]
df_community = pd.DataFrame(df_community, columns=['Hood_ID','Hood_Lat','Hood_Lng','Venue_Latitude','Venue_Longitude','Venue_Name'])
df_community.head()
# Out:
#    Hood_ID   Hood_Lat   Hood_Lng  Venue_Latitude  Venue_Longitude  \
# 0       94  43.676919 -79.425515       43.681654       -79.425904
# 1       94  43.676919 -79.425515       43.672479       -79.415823
# 2       94  43.676919 -79.425515       43.672645       -79.416035
# 3       94  43.676919 -79.425515       43.679558       -79.435122
# 4       94  43.676919 -79.425515       43.681208       -79.428296
#
#                                Venue_Name
# 0                            Rocket Cycle
# 1  Oliphant's Academy of Physical Culture
# 2                       Vive Fitness 24-7
# 3        Tiger Dragon Martial Arts Centre
# 4       Northern Karate Schools - Midtown

# %%
# From a brief review of 500 entries, we note YWCA, community centre, and YMCA may all indicate places where youth come to excel.
upper_names=[name.upper() for name in df_community['Venue_Name']]
df_community_ctr = df_community[['COMMUNITY' in name or 'YMCA' in name or 'YWCA' in name for name in upper_names]].reset_index()
df_community_ctr.drop(columns='index',axis=1,inplace=True)
df_community_ctr.head()
# Out:
#    Hood_ID   Hood_Lat   Hood_Lng  Venue_Latitude  Venue_Longitude  \
# 0      100  43.704689 -79.403590       43.706098       -79.404337
# 1       97  43.687859 -79.397871       43.684917       -79.389555
# 2       97  43.687859 -79.397871       43.696434       -79.393411
# 3       31  43.714672 -79.457108       43.708532       -79.455921
# 4       31  43.714672 -79.457108       43.719992       -79.446111
#
#                                 Venue_Name
# 0  North Toronto Memorial Community Centre
# 1                                     Ywca
# 2        Central Eglinton Community Centre
# 3               Glen Long Community Centre
# 4             San Lorenzo Community Centre

# %%
# Consider instead marking 1, 0 by venues that are youth centers (easier to merge? or can left merge then replace)
# Group dataframe by Hood_ID
df_comm_grouped = df_community_ctr.groupby('Hood_ID').count()
df_comm_grouped.head(10)
df_comm_grouped.drop(columns=['Hood_Lat','Hood_Lng','Venue_Latitude','Venue_Longitude'],axis=1,inplace=True)
df_comm_grouped.rename(columns={'Venue_Name':'Community_Centers'},inplace=True)
df_comm_grouped.reset_index(inplace=True)
df_comm_grouped.head()
# Out:
#    Hood_ID  Community_Centers
# 0        2                  1
# 1        4                  1
# 2       13                  1
# 3       22                  1
# 4       24                  1

# %% [markdown]
# ### 2.4 Create Dataframe with Crime, Population, and Community Center Info <a name='s24'></a>
#
# Start by merging community center dataframe with crimes/location/population data

# %%
# Merge dataframe with crimes
df_toronto = df_crimes
df_toronto = df_toronto.join(df_comm_grouped.set_index('Hood_ID'), on='Hood_ID')
df_toronto['Community_Centers'].replace(np.nan,0,inplace=True)
df_toronto.head(40)
# Out:
#     Hood_ID  LONGITUDE   LATITUDE                      Neighbourhood  \
# 0        94 -79.425515  43.676919                           Wychwood
# 1       100 -79.403590  43.704689                     Yonge-Eglinton
# 2        97 -79.397871  43.687859                     Yonge-St.Clair
# 3        27 -79.488883  43.765736            York University Heights
# 4        31 -79.457108  43.714672                 Yorkdale-Glen Park
# 5       114 -79.496045  43.657420                 Lambton Baby Point
# 6        38 -79.424748  43.754271                   Lansing-Westgate
# 7       105 -79.403978  43.730060                Lawrence Park North
# 8       103 -79.406039  43.717212                Lawrence Park South
# 9        56 -79.366072  43.703797                 Leaside-Bennington
# 10       84 -79.430323  43.647536                    Little Portugal
# 11       19 -79.533345  43.592362                        Long Branch
# 12      132 -79.222517  43.803658                            Malvern
# 13       29 -79.480758  43.715574                         Maple Leaf
# 14       12 -79.573432  43.633542                      Markland Wood
# 15      130 -79.275009  43.820691                           Milliken
# 16       17 -79.500137  43.615924                             Mimico
# 17      135 -79.207041  43.782399                        Morningside
# 18       73 -79.367297  43.656518                          Moss Park
# 19      115 -79.499989  43.688144                       Mount Dennis
# 20        2 -79.587259  43.746868  Mount Olive-Silverstone-Jamestown
# 21       99 -79.384924  43.704852                Mount Pleasant East
# 22      104 -79.393360  43.704435                Mount Pleasant West
# 23       18 -79.510358  43.600589                        New Toronto
# 24       50 -79.405937  43.791536                   Newtonbrook East
# 25       36 -79.431422  43.785830                   Newtonbrook West
# 26       82 -79.412420  43.636681                            Niagara
# 27       68 -79.351260  43.671995                    North Riverdale
# 28       74 -79.375247  43.669623                North St.James Town
# 29       54 -79.312228  43.706800                  O'Connor-Parkview
# 30      121 -79.279708  43.697408                           Oakridge
# 31      107 -79.439785  43.688566                    Oakwood Village
# 32       58 -79.335488  43.696781                      Old East York
# 33       80 -79.418409  43.659157            Palmerston-Little Italy
# 34       45 -79.330180  43.755033                  Parkwoods-Donalda
# 35       23 -79.528282  43.717515               Pelmo Park-Humberlea
# 36       67 -79.354887  43.679700           Playter Estates-Danforth
# 37       46 -79.334948  43.786982                      Pleasant View
# 38       10 -79.544559  43.666051                 Princess-Rosethorn
# 39       72 -79.360509  43.659992                        Regent Park
#
#     Population   Shape__Area  Crime_Score  Community_Centers
# 0        14349  1.682111e+06     0.572987                0.0
# 1        11817  1.650438e+06     1.107409                1.0
# 2        12528  1.161315e+06    -0.747775                2.0
# 3        27593  1.324666e+07    -0.143295                0.0
# 4        14804  6.038326e+06     1.312097                2.0
# 5         7985  1.781938e+06    -0.747494                0.0
# 6        16164  5.346186e+06    -0.616817                1.0
# 7        14607  2.289801e+06    -0.782111                0.0
# 8        15179  3.242277e+06    -0.623865                0.0
# 9        16828  4.784766e+06    -0.729371                1.0
# 10       15559  1.216369e+06    -0.617337                1.0
# 11       10084  2.261880e+06    -0.528889                0.0
# 12       43794  8.866244e+06    -0.244631                0.0
# 13       10111  2.526427e+06    -0.703593                0.0
# 14       10554  2.953752e+06    -0.721816                0.0
# 15       26572  9.477859e+06     0.264332                0.0
# 16       33964  7.059172e+06    -0.052229                0.0
# 17       17455  5.740138e+06     0.401193                0.0
# 18       20506  1.413052e+06     3.267459                3.0
# 19       13593  2.129359e+06     3.476770                1.0
# 20       32954  4.637542e+06     1.125701                1.0
# 21       16775  3.088927e+06    -0.730368                0.0
# 22       29658  1.343312e+06     0.559225                2.0
# 23       11463  3.481239e+06    -0.598659                0.0
# 24       16097  4.084781e+06    -0.629411                0.0
# 25       23831  4.695676e+06    -0.608020                2.0
# 26       31180  3.241279e+06    -0.519488                0.0
# 27       11916  1.786041e+06    -0.525465                2.0
# 28       18615  4.241968e+05    -0.408095                0.0
# 29       18675  4.876767e+06    -0.611428                0.0
# 30       13845  1.878562e+06    -0.458564                1.0
# 31       21210  2.219473e+06     1.171006                2.0
# 32        9233  2.349933e+06    -0.734506                1.0
# 33       13826  1.435237e+06    -0.508828                1.0
# 34       34805  7.464327e+06    -0.180962                0.0
# 35       10722  4.276048e+06     1.309386                0.0
# 36        7804  8.875930e+05    -0.448279                1.0
# 37       15818  2.967493e+06    -0.755158                1.0
# 38       11051  5.171203e+06    -0.622150                0.0
# 39       10803  6.502953e+05     1.380544                4.0

# %% [markdown]
# Create Population Density, eliminate unnecessary columns

# %%
# Calculate population density, community center density, crime rate, eliminate unnecessary columns
df_toronto['Population_Density'] = df_toronto['Population']/df_toronto['Shape__Area']
df_toronto.drop(columns=['Population','Shape__Area'],inplace=True)
df_toronto.head()
# Out:
#    Hood_ID  LONGITUDE   LATITUDE            Neighbourhood  Crime_Score  \
# 0       94 -79.425515  43.676919                 Wychwood     0.572987
# 1      100 -79.403590  43.704689           Yonge-Eglinton     1.107409
# 2       97 -79.397871  43.687859           Yonge-St.Clair    -0.747775
# 3       27 -79.488883  43.765736  York University Heights    -0.143295
# 4       31 -79.457108  43.714672       Yorkdale-Glen Park     1.312097
#
#    Community_Centers  Population_Density
# 0                0.0            0.008530
# 1                1.0            0.007160
# 2                2.0            0.010788
# 3                0.0            0.002083
# 4                2.0            0.002452

# %% [markdown]
# Normalize Population_Density column

# %%
# Copy procedure done for crime_score
pop_density = np.array(df_toronto['Population_Density']).reshape(-1,1)
df_toronto_pop_normalize = scaler.fit(pop_density).transform(pop_density)
df_toronto['Population_Density'] = df_toronto_pop_normalize
df_toronto.head()
# Out:
#    Hood_ID  LONGITUDE   LATITUDE            Neighbourhood  Crime_Score  \
# 0       94 -79.425515  43.676919                 Wychwood     0.572987
# 1      100 -79.403590  43.704689           Yonge-Eglinton     1.107409
# 2       97 -79.397871  43.687859           Yonge-St.Clair    -0.747775
# 3       27 -79.488883  43.765736  York University Heights    -0.143295
# 4       31 -79.457108  43.714672       Yorkdale-Glen Park     1.312097
#
#    Community_Centers  Population_Density
# 0                0.0            0.488915
# 1                1.0            0.202553
# 2                2.0            0.960619
# 3                0.0           -0.858300
# 4                2.0           -0.781267

# %% [markdown]
# ### 2.5 Defining the Data Frame <a name="s25"></a>
# We must define the terms in the dataframe to improve understanding of the following results.
#
# Population_Density: _Normalized measure of population over area_
#
# Crime_Score: _Normalized measure of crime, scaled to the neighborhood population (including Theft, Robbery, Breaking and Entering, Auto Theft, Assault, and Homicide__
#
# Community_Centers: _Count of community centers in the neighborhood. This includes existing YMCAs and YWCAs._

# %% [markdown]
# ## 3. Finding the Best Location for Our Youth Center Pilot Facility <a name="s3"></a>

# %% [markdown]
# #### 3.1 Question: Are youth centers generally established in places of most need? <a name="s31"></a>
# Our heat map, relating youth center density with population and crime density, will help us tell if youth center establishment thus far has been a worthy effort. This can help us make our case to the city of Toronto to fund further projects, once this is successful.

# %%
# Check correlation between Crime_Score, Community_Centers, and Population Density
import seaborn as sns
# %matplotlib inline
corr = df_toronto[['Crime_Score','Community_Centers','Population_Density']].corr()
sns.heatmap(corr,
           xticklabels=['Crime','CommCen','Pop'],
           yticklabels=['Crime','CommCen','Pop'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Analysis:__ Community Centers have a small correlation with population density, but no correlation at all with crime.
#
# __Conclusion:__ It looks like community centers may be placed where populations are dense, so the at-risk youth may not be served. Let's take a closer look by using clustering.

# %% [markdown]
# ### 3.2 Question: Can we find a cluster of neighborhoods that need YMCAs? <a name='s32'></a>
# We cluster neighborhoods based on population density, crime rates, and community centers / youth development centers to find neighborhoods that most desperately need YMCAs.

# %% [markdown]
# #### 3.2.1 Cluster each Neighborhood <a name='s321'></a>

# %%
# Find optimal number of clusters
df_cluster = df_toronto[['Crime_Score','Community_Centers','Population_Density']]
cluster_maximum = 10
error = []
for i in range(1,cluster_maximum+1):
    kmeans = KMeans(n_clusters = i, random_state=4).fit(df_cluster)
    error.append(kmeans.inertia_)
    
import matplotlib.pyplot as plt
plt.plot(range(1,cluster_maximum+1),error)
plt.xlabel('Number of Clusters')
plt.ylabel('Intra-cluster Error')
plt.title('Finding Optimal Clusters for K-Means')
# Out:
# Text(0.5, 1.0, 'Finding Optimal Clusters for K-Means')

# %%
# Create dataframe with only clustering data. Last elbow is at k=6
df_cluster = df_toronto[['Crime_Score','Community_Centers','Population_Density']]
k_clusters = 6 # define number of clusters
kmeans = KMeans(n_clusters = k_clusters, random_state=4).fit(df_cluster)
kmeans.labels_
# Out:
# array([1, 1, 0, 4, 1, 4, 0, 4, 4, 0, 0, 4, 4, 4, 4, 4, 4, 1, 2, 2, 1, 4,
#        5, 4, 4, 0, 4, 0, 3, 4, 0, 5, 0, 0, 4, 1, 0, 0, 4, 5, 2, 4, 5, 0,
#        4, 0, 1, 4, 5, 0, 4, 4, 4, 1, 5, 4, 4, 0, 0, 2, 1, 0, 1, 1, 4, 1,
#        1, 4, 0, 0, 4, 4, 0, 1, 4, 0, 4, 0, 4, 4, 2, 4, 1, 0, 0, 4, 4, 0,
#        5, 0, 4, 0, 4, 5, 0, 4, 4, 5, 1, 4, 0, 4, 0, 4, 4, 1, 1, 1, 0, 5,
#        4, 1, 4, 0, 4, 2, 0, 4, 4, 1, 5, 1, 0, 5, 4, 1, 1, 4, 2, 0, 4, 0,
#        4, 0, 1, 1, 0, 4, 4, 4], dtype=int32)

# %% [markdown]
# Enter cluster into the dataframe

# %%
df_toronto.insert(0, 'Cluster',kmeans.labels_)
df_toronto.head()
# Out:
#    Cluster  Hood_ID  LONGITUDE   LATITUDE            Neighbourhood  \
# 0        1       94 -79.425515  43.676919                 Wychwood
# 1        1      100 -79.403590  43.704689           Yonge-Eglinton
# 2        0       97 -79.397871  43.687859           Yonge-St.Clair
# 3        4       27 -79.488883  43.765736  York University Heights
# 4        1       31 -79.457108  43.714672       Yorkdale-Glen Park
#
#    Crime_Score  Community_Centers  Population_Density
# 0     0.572987                0.0            0.488915
# 1     1.107409                1.0            0.202553
# 2    -0.747775                2.0            0.960619
# 3    -0.143295                0.0           -0.858300
# 4     1.312097                2.0           -0.781267

# %% [markdown]
# #### 3.2.2 Show Clusters on Folium Map <a name="s322"></a>

# %%
# Visualize the clusters!
latitude, longitude = 43.6523, -79.3832
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# colors
x = np.arange(k_clusters)
ys = [i + x + (i*x)**2 for i in range(k_clusters)]
colors_array = cm.rainbow(np.linspace(0,1,len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# markers will correspond to clustered color scheme
markers_colors = []
for lat, lon, hood, cluster in zip(df_toronto['LATITUDE'],df_toronto['LONGITUDE'],df_toronto['Neighbourhood'],df_toronto['Cluster']):
    label = folium.Popup(str(hood)+', Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius = 5,
        popup = label,
        color = rainbow[cluster],
        fill = True,
        fill_color = rainbow[cluster],
        fill_opacity = 0.7).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 3.2.3 Interpreting our Clusters <a name="s323"></a>
# Here we want to find out which of the clusters we should target for our YMCA Pilot Program.

# %% [markdown]
# __Cluster 0__

# %%
df_toronto[df_toronto['Cluster']==0]
# Out:
#      Cluster  Hood_ID  LONGITUDE   LATITUDE  \
# 2          0       97 -79.397871  43.687859
# 6          0       38 -79.424748  43.754271
# 9          0       56 -79.366072  43.703797
# 10         0       84 -79.430323  43.647536
# 25         0       36 -79.431422  43.785830
# 27         0       68 -79.351260  43.671995
# 30         0      121 -79.279708  43.697408
# 32         0       58 -79.335488  43.696781
# 33         0       80 -79.418409  43.659157
# 36         0       67 -79.354887  43.679700
# 37         0       46 -79.334948  43.786982
# 43         0       98 -79.379669  43.682820
# 45         0       89 -79.485708  43.659269
# 49         0       70 -79.335651  43.649292
# 57         0       55 -79.349984  43.707749
# 58         0       81 -79.415342  43.650176
# 61         0       77 -79.377202  43.633880
# 68         0       51 -79.401484  43.770602
# 69         0       37 -79.427558  43.771210
# 72         0       64 -79.315407  43.676773
# 75         0      128 -79.265612  43.788658
# 77         0       95 -79.404001  43.671585
# 83         0       39 -79.420227  43.731486
# 84         0      112 -79.479473  43.693216
# 87         0       24 -79.521979  43.764890
# 89         0      108 -79.452851  43.699024
# 91         0       57 -79.355630  43.688825
# 94         0      109 -79.455212  43.688569
# 100        0      123 -79.235530  43.721121
# 102        0       66 -79.329819  43.684025
# 108        0       83 -79.437341  43.655428
# 113        0       32 -79.437409  43.720345
# 116        0       44 -79.332646  43.715930
# 122        0       53 -79.341241  43.771144
# 129        0       22 -79.542367  43.743430
# 131        0      125 -79.272470  43.735364
# 133        0       90 -79.471440  43.667890
# 136        0       78 -79.397240  43.653554
#
#                          Neighbourhood  Crime_Score  Community_Centers  \
# 2                       Yonge-St.Clair    -0.747775                2.0
# 6                     Lansing-Westgate    -0.616817                1.0
# 9                   Leaside-Bennington    -0.729371                1.0
# 10                     Little Portugal    -0.617337                1.0
# 25                    Newtonbrook West    -0.608020                2.0
# 27                     North Riverdale    -0.525465                2.0
# 30                            Oakridge    -0.458564                1.0
# 32                       Old East York    -0.734506                1.0
# 33             Palmerston-Little Italy    -0.508828                1.0
# 36            Playter Estates-Danforth    -0.448279                1.0
# 37                       Pleasant View    -0.755158                1.0
# 43                 Rosedale-Moore Park    -0.538801                1.0
# 45        Runnymede-Bloor West Village    -0.595145                1.0
# 49                     South Riverdale    -0.444965                1.0
# 57                    Thorncliffe Park    -0.757695                2.0
# 58                   Trinity-Bellwoods    -0.476521                1.0
# 61   Waterfront Communities-The Island    -0.053615                1.0
# 68                     Willowdale East    -0.704779                1.0
# 69                     Willowdale West    -0.576385                1.0
# 72                   Woodbine Corridor    -0.662952                2.0
# 75        Agincourt South-Malvern West    -0.502749                1.0
# 77                               Annex     0.311593                1.0
# 83                Bedford Park-Nortown    -0.557096                1.0
# 84             Beechborough-Greenbrook    -0.544606                1.0
# 87                         Black Creek    -0.487557                1.0
# 89                Briar Hill-Belgravia    -0.535226                2.0
# 91                     Broadview North    -0.731477                1.0
# 94                  Caledonia-Fairbank    -0.641263                2.0
# 100                         Cliffcrest    -0.593379                1.0
# 102                           Danforth    -0.519993                1.0
# 108                     Dufferin Grove    -0.437636                1.0
# 113                Englemount-Lawrence    -0.723011                1.0
# 116                    Flemingdon Park    -0.780368                2.0
# 122                         Henry Farm    -0.605102                1.0
# 129                         Humbermede    -0.368727                1.0
# 131                            Ionview    -0.751940                1.0
# 133                      Junction Area    -0.575516                2.0
# 136               Kensington-Chinatown     0.360868                1.0
#
#      Population_Density
# 2              0.960619
# 6             -0.661787
# 9             -0.558660
# 10             1.379279
# 25            -0.233085
# 27             0.100545
# 30             0.246451
# 32            -0.472559
# 33             0.719374
# 36             0.543654
# 37            -0.179732
# 43            -0.357184
# 45             0.026530
# 49            -0.762315
# 57             0.117150
# 58             0.706464
# 61            -0.266975
# 68             0.788735
# 69            -0.066254
# 72             0.348699
# 75            -0.663041
# 77             0.992390
# 83            -0.413678
# 84            -0.544056
# 87             0.021531
# 89             0.334072
# 91             0.082635
# 94             0.053318
# 100           -0.830544
# 102            0.510352
# 108            0.480630
# 113            0.050467
# 116            0.559445
# 122           -0.026652
# 129           -0.558943
# 131            0.166022
# 133           -0.152958
# 136            1.149719

# %% [markdown]
# __Analysis:__ Cluster 0 neighborhoods have medium population density (-1 to 1 generally) and community center availability (1 to 2), with moderately low crime scores (hanging around -0.7 to -0.5 the normalized data).
#
# __Conclusion:__ This is NOT a good cluster to pursue.
#
# -----

# %% [markdown]
# __Cluster 1__

# %%
df_toronto[df_toronto['Cluster']==1]
# Out:
#      Cluster  Hood_ID  LONGITUDE   LATITUDE  \
# 0          1       94 -79.425515  43.676919
# 1          1      100 -79.403590  43.704689
# 4          1       31 -79.457108  43.714672
# 17         1      135 -79.207041  43.782399
# 20         1        2 -79.587259  43.746868
# 35         1       23 -79.528282  43.717515
# 46         1       28 -79.498091  43.711609
# 53         1      118 -79.302919  43.780130
# 60         1       43 -79.314874  43.728489
# 62         1      136 -79.176676  43.767490
# 63         1        1 -79.596356  43.716180
# 65         1      113 -79.515723  43.702716
# 66         1       91 -79.460244  43.673962
# 73         1       60 -79.311164  43.694107
# 82         1       49 -79.382118  43.796802
# 98         1      120 -79.281382  43.713592
# 105        1      126 -79.278908  43.759274
# 106        1       93 -79.438541  43.665677
# 107        1       26 -79.490497  43.733292
# 111        1      138 -79.245598  43.740922
# 119        1       25 -79.513465  43.745636
# 121        1      140 -79.195055  43.748829
# 125        1      134 -79.177472  43.790775
# 126        1       48 -79.354804  43.802988
# 134        1      110 -79.471437  43.685727
# 135        1      124 -79.260382  43.725556
#
#                            Neighbourhood  Crime_Score  Community_Centers  \
# 0                               Wychwood     0.572987                0.0
# 1                         Yonge-Eglinton     1.107409                1.0
# 4                     Yorkdale-Glen Park     1.312097                2.0
# 17                           Morningside     0.401193                0.0
# 20     Mount Olive-Silverstone-Jamestown     1.125701                1.0
# 35                  Pelmo Park-Humberlea     1.309386                0.0
# 46                                Rustic     1.205716                1.0
# 53                Tam O'Shanter-Sullivan     0.649984                1.0
# 60                      Victoria Village     0.440535                1.0
# 62                             West Hill     0.953680                1.0
# 63                West Humber-Clairville     1.296193                0.0
# 65                                Weston     1.581863                0.0
# 66                    Weston-Pellam Park     1.065567                1.0
# 73                      Woodbine-Lumsden     1.641777                0.0
# 82                 Bayview Woods-Steeles     0.644136                1.0
# 98                   Clairlea-Birchmount     0.194783                1.0
# 105                          Dorset Park     0.915909                0.0
# 106  Dovercourt-Wallace Emerson-Junction     0.976829                1.0
# 107                 Downsview-Roding-CFB     1.251532                0.0
# 111                        Eglinton East     1.052277                0.0
# 119               Glenfield-Jane Heights     0.725364                0.0
# 121                            Guildwood     1.070136                0.0
# 125                       Highland Creek     0.807224                0.0
# 126                    Hillcrest Village     0.430746                1.0
# 134             Keelesdale-Eglinton West     1.138831                0.0
# 135                         Kennedy Park     0.577662                1.0
#
#      Population_Density
# 0              0.488915
# 1              0.202553
# 4             -0.781267
# 17            -0.658151
# 20             0.191270
# 35            -0.769611
# 46            -0.302676
# 53            -0.235895
# 60            -0.524125
# 62            -0.698913
# 63            -1.062654
# 65             0.171844
# 66             0.294121
# 73             0.080278
# 82            -0.621352
# 98            -0.531324
# 105           -0.424553
# 106            0.760493
# 107           -0.805016
# 111            0.183010
# 119           -0.056354
# 121           -0.748859
# 125           -0.796099
# 126           -0.637761
# 134            0.026224
# 135           -0.294331

# %% [markdown]
# __Analysis:__ This neighborhood has somewhat high crime scores, around 0.5 to 1.5, with fewer community centers (0 to 1) and middle-of-the-road population density (-1 to 0.5)
#
# __Conclusion:__ This is a FAIR cluster to pursue because it has medium-high crime, but higher population density would serve a bigger population. These communities would benefit from more community centers.
#
# -----

# %% [markdown]
# __Cluster 2__

# %%
df_toronto[df_toronto['Cluster']==2]
# Out:
#      Cluster  Hood_ID  LONGITUDE   LATITUDE        Neighbourhood  Crime_Score  \
# 18         2       73 -79.367297  43.656518            Moss Park     3.267459
# 19         2      115 -79.499989  43.688144         Mount Dennis     3.476770
# 40         2        4 -79.566228  43.723725      Rexdale-Kipling     3.069128
# 59         2       79 -79.401180  43.662506           University     2.348974
# 80         2       76 -79.385721  43.657511  Bay Street Corridor     2.774280
# 115        2       13 -79.568939  43.645063  Etobicoke West Mall     2.448836
# 128        2       21 -79.556175  43.758920        Humber Summit     4.631042
#
#      Community_Centers  Population_Density
# 18                 3.0            1.738790
# 19                 1.0            0.040339
# 40                 1.0           -0.415476
# 59                 2.0           -0.162410
# 80                 0.0            1.685655
# 115                1.0            0.084411
# 128                0.0           -0.967912

# %% [markdown]
# __Analysis:__ This cluster has very high average crime scores (2.3-4.6), a variety of community centers, and medium population density (-1 to 1.7 mostly).
#
# __Conclusion:__ This is a GREAT cluster to consider. Crime scores are the highest of any cluster, with many opportunities in low community-center-density and medium population density neighborhoods.
#
# -----

# %% [markdown]
# __Cluster 3__

# %%
df_toronto[df_toronto['Cluster']==3]
# Out:
#     Cluster  Hood_ID  LONGITUDE   LATITUDE        Neighbourhood  Crime_Score  \
# 28        3       74 -79.375247  43.669623  North St.James Town    -0.408095
#
#     Community_Centers  Population_Density
# 28                0.0             7.87608

# %% [markdown]
# __Analysis:__ This singular neighborhood has extreme population density with no community centers, but crime is lower than average
#
# __Conclusion:__ This is a GOOD place to build a YMCA due to its very high population density and lack of community centers. However, low-end crime means impact will be limited.
#
# -----

# %% [markdown]
# __Cluster 4__

# %%
df_toronto[df_toronto['Cluster']==4]
# Out:
#      Cluster  Hood_ID  LONGITUDE   LATITUDE  \
# 3          4       27 -79.488883  43.765736
# 5          4      114 -79.496045  43.657420
# 7          4      105 -79.403978  43.730060
# 8          4      103 -79.406039  43.717212
# 11         4       19 -79.533345  43.592362
# 12         4      132 -79.222517  43.803658
# 13         4       29 -79.480758  43.715574
# 14         4       12 -79.573432  43.633542
# 15         4      130 -79.275009  43.820691
# 16         4       17 -79.500137  43.615924
# 21         4       99 -79.384924  43.704852
# 23         4       18 -79.510358  43.600589
# 24         4       50 -79.405937  43.791536
# 26         4       82 -79.412420  43.636681
# 29         4       54 -79.312228  43.706800
# 34         4       45 -79.330180  43.755033
# 38         4       10 -79.544559  43.666051
# 41         4      111 -79.494420  43.674790
# 44         4      131 -79.186343  43.821201
# 47         4      139 -79.216813  43.738652
# 50         4       40 -79.379037  43.756246
# 51         4      116 -79.321207  43.812959
# 52         4       16 -79.501128  43.635518
# 55         4       63 -79.299601  43.671050
# 56         4        3 -79.563491  43.737988
# 64         4       35 -79.452418  43.778813
# 67         4      119 -79.298637  43.748572
# 70         4        7 -79.554221  43.683645
# 71         4      137 -79.228586  43.766740
# 74         4      129 -79.266712  43.805441
# 76         4       20 -79.541611  43.604937
# 78         4       42 -79.349718  43.737657
# 79         4       34 -79.456055  43.764813
# 81         4       52 -79.377117  43.776361
# 85         4      127 -79.257400  43.760366
# 86         4      122 -79.265093  43.694682
# 90         4       41 -79.378904  43.731013
# 92         4       30 -79.485589  43.701326
# 95         4       96 -79.408007  43.681852
# 96         4      133 -79.150843  43.782376
# 99         4       33 -79.446303  43.741978
# 101        4       92 -79.447469  43.677661
# 103        4       59 -79.331403  43.689468
# 104        4       47 -79.353644  43.783294
# 110        4        9 -79.522458  43.670886
# 112        4        5 -79.548983  43.721519
# 114        4       11 -79.580445  43.658017
# 117        4      102 -79.428143  43.704218
# 118        4      101 -79.414318  43.694526
# 124        4       87 -79.467872  43.645065
# 127        4        8 -79.522416  43.692233
# 130        4      106 -79.427683  43.691370
# 132        4       14 -79.543317  43.633463
# 137        4        6 -79.547863  43.698993
# 138        4       15 -79.510577  43.653520
# 139        4      117 -79.314084  43.795716
#
#                          Neighbourhood  Crime_Score  Community_Centers  \
# 3              York University Heights    -0.143295                0.0
# 5                   Lambton Baby Point    -0.747494                0.0
# 7                  Lawrence Park North    -0.782111                0.0
# 8                  Lawrence Park South    -0.623865                0.0
# 11                         Long Branch    -0.528889                0.0
# 12                             Malvern    -0.244631                0.0
# 13                          Maple Leaf    -0.703593                0.0
# 14                       Markland Wood    -0.721816                0.0
# 15                            Milliken     0.264332                0.0
# 16                              Mimico    -0.052229                0.0
# 21                 Mount Pleasant East    -0.730368                0.0
# 23                         New Toronto    -0.598659                0.0
# 24                    Newtonbrook East    -0.629411                0.0
# 26                             Niagara    -0.519488                0.0
# 29                   O'Connor-Parkview    -0.611428                0.0
# 34                   Parkwoods-Donalda    -0.180962                0.0
# 38                  Princess-Rosethorn    -0.622150                0.0
# 41                   Rockcliffe-Smythe     0.176180                0.0
# 44                               Rouge    -0.726562                0.0
# 47                 Scarborough Village    -0.587571                0.0
# 50                St.Andrew-Windfields    -0.620163                0.0
# 51                             Steeles    -0.766578                0.0
# 52                 Stonegate-Queensway    -0.718352                0.0
# 55                         The Beaches    -0.691012                0.0
# 56        Thistletown-Beaumond Heights    -0.588379                0.0
# 64                 Westminster-Branson    -0.776303                0.0
# 67                    Wexford/Maryvale     0.164481                0.0
# 70    Willowridge-Martingrove-Richview     0.171878                0.0
# 71                              Woburn    -0.659516                0.0
# 74                     Agincourt North    -0.734775                0.0
# 76                           Alderwood    -0.704906                0.0
# 78                   Banbury-Don Mills    -0.689943                0.0
# 79                      Bathurst Manor    -0.734402                0.0
# 81                     Bayview Village    -0.677769                0.0
# 85                             Bendale     0.020764                0.0
# 86               Birchcliffe-Cliffside    -0.601139                0.0
# 90   Bridle Path-Sunnybrook-York Mills    -0.551071                0.0
# 92                 Brookhaven-Amesbury    -0.581705                0.0
# 95                           Casa Loma    -0.717020                0.0
# 96              Centennial Scarborough    -0.768616                0.0
# 99                        Clanton Park    -0.624139                0.0
# 101             Corso Italia-Davenport    -0.556860                0.0
# 103                 Danforth East York    -0.756359                0.0
# 104                 Don Valley Village    -0.668247                0.0
# 110           Edenbridge-Humber Valley    -0.682778                0.0
# 112                   Elms-Old Rexdale    -0.578114                0.0
# 114     Eringate-Centennial-West Deane     0.267075                0.0
# 117                  Forest Hill North    -0.646186                0.0
# 118                  Forest Hill South    -0.615484                0.0
# 124                  High Park-Swansea     0.169856                0.0
# 127           Humber Heights-Westmount    -0.729608                0.0
# 130                 Humewood-Cedarvale    -0.743502                0.0
# 132         Islington-City Centre West    -0.068784                0.0
# 137      Kingsview Village-The Westway    -0.760129                0.0
# 138                     Kingsway South    -0.592038                0.0
# 139                         L'Amoreaux    -0.723477                0.0
#
#      Population_Density
# 3             -0.858300
# 5             -0.357209
# 7              0.039408
# 8             -0.315311
# 11            -0.361981
# 12            -0.261437
# 13            -0.457295
# 14            -0.546941
# 15            -0.707732
# 16            -0.288200
# 21            -0.158781
# 23            -0.605509
# 24            -0.470119
# 26             0.716533
# 29            -0.493385
# 34            -0.319227
# 38            -0.847014
# 41            -0.376844
# 44            -1.034715
# 47            -0.184523
# 50            -0.783677
# 51            -0.165572
# 52            -0.634808
# 55            -0.040283
# 56            -0.645318
# 64             0.203301
# 67            -0.725212
# 70            -0.454465
# 71            -0.387448
# 74            -0.455846
# 76            -0.787631
# 78            -0.717249
# 79            -0.596804
# 81            -0.426958
# 85            -0.453969
# 86            -0.518399
# 90            -1.074489
# 92            -0.235662
# 95            -0.101471
# 96            -0.782984
# 99            -0.462662
# 101            0.273401
# 103            0.346704
# 104            0.048315
# 110           -0.704592
# 112           -0.619457
# 114           -0.844300
# 117            0.411806
# 118           -0.389325
# 124           -0.360530
# 127           -0.477321
# 130            0.310524
# 132           -0.727861
# 137           -0.385657
# 138           -0.559286
# 139           -0.008756

# %% [markdown]
# __Analysis:__ This cluster has 0 community centers total (0), below average crime (generally -0.8 to 0.2), and slightly below average population density (generally -1 to 0.5)
#
# __Conclusion:__ This cluster is a BAD choice. It is neither dangerous nor populous enough to pursue, even though it has a low community center density. This is NOT a good cluster to build a YMCA in.
#
# -----

# %%
df_toronto[df_toronto['Cluster']==5]
# Out:
#      Cluster  Hood_ID  LONGITUDE   LATITUDE                    Neighbourhood  \
# 22         5      104 -79.393360  43.704435              Mount Pleasant West
# 31         5      107 -79.439785  43.688566                  Oakwood Village
# 39         5       72 -79.360509  43.659992                      Regent Park
# 42         5       86 -79.442992  43.646123                     Roncesvalles
# 48         5       85 -79.439338  43.636700                   South Parkdale
# 54         5       61 -79.295901  43.694998                    Taylor-Massey
# 88         5       69 -79.337394  43.676173                      Blake-Jones
# 93         5       71 -79.366107  43.667648  Cabbagetown-South St.James Town
# 97         5       75 -79.379017  43.659649            Church-Yonge Corridor
# 109        5       62 -79.299359  43.684174                East End-Danforth
# 120        5       65 -79.324318  43.672612                Greenwood-Coxwell
# 123        5       88 -79.466302  43.657565                  High Park North
#
#      Crime_Score  Community_Centers  Population_Density
# 22      0.559225                2.0            3.319844
# 31      1.171006                2.0            0.703298
# 39      1.380544                4.0            2.177725
# 42      0.785983                3.0            0.786109
# 48      0.467738                2.0            0.702745
# 54      0.571652                3.0            1.789377
# 88     -0.576005                4.0            0.422016
# 93     -0.325795                3.0            0.426031
# 97      0.887859                1.0            3.505621
# 109    -0.587525                4.0            0.399382
# 120    -0.589076                3.0            0.504778
# 123    -0.712046                3.0            1.166696

# %% [markdown]
# __Analysis:__ This cluster has higher population density than average (0.4 - 3.3), and generally high community center numbers given population density for the most part. Crime is middle of the road (-0.8 to 1.4).
#
# __Conclusion:__ This cluster is a BAD choice due to its copious community centers and medium danger levels. However, Church-Yonge Corridor may be a solid choice from this cluster.
#
# -----

# %% [markdown]
# # 4. Neighborhood Choice <a name="s4"></a>

# %% [markdown]
# The neighborhood of choice is __Humber Summit__, from cluster 2.
#
# __Stakeholder Information:__ We originally heard from our stakeholder that we want a region that has high crime rates, low concentrations of community centers, and high population density. Most importantly, high crime rates. In the analysis of clusters, we discovered that cluster 1 was the best match for our intentions.
#
# __Explanation:__ Humber Summit can benefit from this effort, as it has a 4.63 crime score, and 0 Community Centers from within 1 km from neighborhood center. However, Humber Summit has a low population density (-1 when normalized), but is still sizable for the city.
#
# __Future Projects:__ A future project is the "University" neighborhood, in cluster 2. It has no community centers, and a crime score of 2.35. Its population density is middle-of-the-road, and it is bordered by "Bay Street Corridor", also in cluster 1, and "Kensington Chinatown", in cluster 2. These two neighborhoods also have above average crime scores, and only one community center within 1 km of neighborhood center. This means that a community center in the University neighborhood may attract the youth from those two neighborhoods as well.
#
# -----
#
# That's it! Please feel free to contact me using the info at the top of the notebook. I would love to hear your feedback.
